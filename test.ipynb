# %% [markdown]
# # Hello World
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/CreekCS/ai-ml-textbook-labs/blob/main/test.ipynb)

# %% [markdown]
# # LAB INSTRUCTIONS
# To save your work, you **must** create your own copy:
# 1. Click **File**
# 2. Select **Save a copy in Drive**
# 3. Rename the file to `[YourName]_Lab1.ipynb`
#
# You must do this for every lab.

# %%
print("Hello World")

print("Make sure you have clicked 'File > Save a copy in Drive' before starting.")
